# %% [markdown]
# ### **Pseudocódigo**
# #### 1.listar los archivos de cada una de las carpetas de la ELCA
# ## **Hogares**
# #### 2.Hogares urbanos: de los archivos con terminación "csv.tab" cargar en el ambiente el correspondiente a "UHogar-csv.tab"
# #### 3.Hogares urbanos: usando las llaves (ej.consecutivo y consecutivo_c) y de acuerdo con la unidad de análisis, unir a "UHogar-csv.tab", "UGastos-csv.tab", "UChoques-csv.tab", "UComunidades-csv.tab"
# #### 4.Hogares urbanos: dejo en el ambiente la base consolidada como Uhogares_unificada_2010.csv
# #### 5.Hogares rurales: de los archivos con terminación "csv.tab" cargar en el ambiente el correspondiente a "RHogar-csv.tab"
# #### 6.Hogares rurales: usando las llaves (ej.consecutivo y consecutivo_c) y de acuerdo con la unidad de análisis, unir a "RHogar-csv.tab", "RActivos_hogar-csv.tab", "RGastos-csv.tab", "RChoques-csv.tab", "RComunidades-csv.tab"
# #### 7.Hogares rurales: dejo en el ambiente la base consolidada como Rhogares_unificada_2010.csv
# #### 8.Hogares: uno Rhogares_unificada_2010.csv a Uhogares_unificada_2010.csv y la guardo como hogares_elca_2010.csv
# ## **Personas**
# #### 9.Personas urbanas: de los archivos con terminación "csv.tab" cargar en el ambiente el correspondiente a "Upersonas-csv.tab"
# #### 10.Personas urbanas: usando las llaves (e.llaveper y llave) y de acuerdo con la unidad de análisis, unir a "Upersonas-csv.tab", "UNinosde0a9-csv.tab",
# #### 11.Personas urbanas: dejo en el ambiente la base consolidada como Upersonas_unificada_2010.csv
# #### 12.Personas rurales: de los archivos con terminación "csv.tab" cargar en el ambiente el correspondiente a "Rpersonas-csv.tab"
# #### 13.Personas rurales: usando las llaves (e.llaveper y llave) y de acuerdo con la unidad de análisis, unir a "Rpersonas-csv.tab", "RNinosde0a9-csv.tab",
# #### 14.Personas rurales: dejo en el ambiente la base consolidada como Rpersonas_unificada_2010.csv
# #### 15.Hogares: uno Rpersonas_unificada_2010.csv a Upersonas_unificada_2010.csv y la guardo como personas_elca_2010.csv
# ## **Unificación de todos**
# #### 16. Cargo la base de "hogares_elca_2010.csv" y incluyo la base de "hogares_elca_2013.csv" y "hogares_elca_2016.csv"
# #### 17. guardo la base consolidada como "panel_hogares_elca.csv"
# #### 18. Cargo la base de "personas_elca_2010.csv" y incluyo la base de "personas_elca_2013.csv" y "personas_elca_2016.csv"
# #### 19. Guardo la base consolidada como "panel_personas_elca.csv"
# #### 20. Cargo la base de panel_hogares_elca.csv y agrego las variables seleccionadas del "panel_personas_elca.csv"
# #### 21. Guardo la base como "panel_elca_consolidado.csv"
